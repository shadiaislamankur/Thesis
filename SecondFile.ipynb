# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df= pd.read_csv('/content/drive/MyDrive/Datasets/diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.tail(10)#first 10 row
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
df[80:85] #from row number 80 to 84 total 5 row
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 80            3      113             44             13        0  22.4
# 81            2       74              0              0        0   0.0
# 82            7       83             78             26       71  29.3
# 83            0      101             65             28        0  24.6
# 84            5      137            108              0        0  48.8
#
#     DiabetesPedigreeFunction  Age  Outcome
# 80                     0.140   22        0
# 81                     0.102   22        0
# 82                     0.767   36        0
# 83                     0.237   22        0
# 84                     0.227   37        1

# %%
df["BMI"] #only BMI colum
# Out:
# 0      33.600000
# 1      26.600000
# 2      23.300000
# 3      28.100000
# 4      31.992578
#          ...
# 763    32.900000
# 764    36.800000
# 765    26.200000
# 766    30.100000
# 767    30.400000
# Name: BMI, Length: 768, dtype: float64

# %%
df['BMI'] .head() #first 5 sample of colum 'BMI'

# %%
df.loc[(df.Age==22)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(color_codes="red")
sns.displot(data=df['BMI']).set(title="Distribution of Scores",xlabel="Scores")

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
z_score=(df['BMI'] - df['BMI'].mean())/df['BMI'].std()

# %%
z_score
# Out:
# 0      0.203880
# 1     -0.683976
# 2     -1.102537
# 3     -0.493721
# 4      1.408828
#          ...
# 763    0.115094
# 764    0.609757
# 765   -0.734711
# 766   -0.240048
# 767   -0.201997
# Name: BMI, Length: 768, dtype: float64

# %%
for i in z_score:
    if i > 4:
        print("you have outlier", i)
    elif i < -4:
        print("you have outlier", i)
    else:
        continue
# Out:
# you have outlier -4.057829473903507
# you have outlier -4.057829473903507
# you have outlier -4.057829473903507
# you have outlier -4.057829473903507
# you have outlier -4.057829473903507
# you have outlier 4.452905629565911
# you have outlier -4.057829473903507
# you have outlier -4.057829473903507
# you have outlier -4.057829473903507
# you have outlier -4.057829473903507
# you have outlier -4.057829473903507
# you have outlier -4.057829473903507

# %%
index=z_score.index[z_score==4.452905629565911][0]

# %%
index
# Out:
# 177

# %%
df['BMI'][177]
# Out:
# 67.1

# %%
df['BMI'][4] = df['BMI'].mean()
# Out:
# <ipython-input-31-3e5dbc5b32b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BMI'][4] = df['BMI'].mean()

# %%
df['BMI'][177]
# Out:
# 67.1

# %% [markdown]
# Duplicate value Handeling

# %%
duplicates = df[df.duplicated(keep='first')]
duplicates
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
df_no_duplicates = df.drop_duplicates()

# %%
duplicates=df_no_duplicates[df_no_duplicates[df_no_duplicates.duplicated(keep='first')]]
duplicates
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            NaN      NaN            NaN            NaN      NaN  NaN
# 1            NaN      NaN            NaN            NaN      NaN  NaN
# 2            NaN      NaN            NaN            NaN      NaN  NaN
# 3            NaN      NaN            NaN            NaN      NaN  NaN
# 4            NaN      NaN            NaN            NaN      NaN  NaN
# ..           ...      ...            ...            ...      ...  ...
# 763          NaN      NaN            NaN            NaN      NaN  NaN
# 764          NaN      NaN            NaN            NaN      NaN  NaN
# 765          NaN      NaN            NaN            NaN      NaN  NaN
# 766          NaN      NaN            NaN            NaN      NaN  NaN
# 767          NaN      NaN            NaN            NaN      NaN  NaN
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                         NaN  NaN      NaN
# ...

# %%
df_no_duplicates
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0              6      148             72             35        0  33.600000
# 1              1       85             66             29        0  26.600000
# 2              8      183             64              0        0  23.300000
# 3              1       89             66             23       94  28.100000
# 4              0      137             40             35      168  31.978115
# ..           ...      ...            ...            ...      ...        ...
# 763           10      101             76             48      180  32.900000
# 764            2      122             70             27        0  36.800000
# 765            5      121             72             23      112  26.200000
# 766            1      126             60              0        0  30.100000
# 767            1       93             70             31        0  30.400000
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %% [markdown]
# ***Feature Engineering***

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=2)
plt.subplots(figsize=(20, 20))
heat_plot = sns.heatmap(df_no_duplicates.corr(method='pearson'), annot=True, cmap='RdYlGn', annot_kws={'size': 20})#person correlation or heatmap

plt.yticks(fontsize=35)
plt.xticks(fontsize=35)
plt.show()

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
correlations = df_no_duplicates.corr(method='pearson') #finding exact correlation values by descending order
print(correlations['BloodPressure'].sort_values(ascending=False).to_string())
# Out:
# BloodPressure               1.000000
# BMI                         0.284937
# Age                         0.239528
# SkinThickness               0.207371
# Glucose                     0.152590
# Pregnancies                 0.141282
# Insulin                     0.088933
# Outcome                     0.065068
# DiabetesPedigreeFunction    0.041265
